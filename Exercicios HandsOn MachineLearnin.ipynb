# %%
######## Logistic Regression

from sklearn import datasets
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
import numpy as np

iris = datasets.load_iris()

X = iris['data'][:,3:] ##petal width
y = (iris['target'] == 2).astype(np.int) #1 if virginica, else 0

##modelo
log_reg = LogisticRegression()
log_reg.fit(X,y)

X_new = np.linspace(0,3,1000).reshape(-1,1)
y_proba = log_reg.predict_proba(X_new)

plt.plot(X_new, y_proba[:,1], 'g-', label='Iris-Virginica')
plt.plot(X_new, y_proba[:,0], 'g-', label='Not Iris-Virginica')
# Out:
# /home/reinaldo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
